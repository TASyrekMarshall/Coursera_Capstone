# %%
# Capstone Project Notebook

# %%
import pandas as pd
import numpy as np

# %%
print ("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
import numpy as np 
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import json 
# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim 
import requests 
from pandas.io.json import json_normalize 

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans
# !conda install -c conda-forge folium=0.5.0 --yes 
import folium 
print('Libraries imported.')
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     openssl-1.1.1e             |       h516909a_0         2.1 MB  conda-forge
#     python_abi-3.6             |          1_cp36m           4 KB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     certifi-2019.11.28         |   py36h9f0ad1d_1         149 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         2.5 MB
#
# The following NEW packages will be INSTALLED:
#
#     geographiclib:   1.50-py_0         conda-forge
#     geopy:           1.21.0-py_0       conda-forge
#     python_abi:      3.6-1_cp36m       conda-forge
#
# The following packages will be UPDATED:
#
#     ca-certificates: 2019.11.27-0                  --> 2019.11.28-hecc5488_0     conda-forge
#     certifi:         2019.11.28-py36_0             --> 2019.11.28-py36h9f0ad1d_1 conda-forge
#     openssl:         1.1.1d-h7b6447c_3             --> 1.1.1e-h516909a_0         conda-forge
#
#
# Downloading and Extracting Packages
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# openssl-1.1.1e       | 2.1 MB    | ##################################### | 100%
# python_abi-3.6       | 4 KB      | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# certifi-2019.11.28   | 149 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         673 KB
#
# The following NEW packages will be INSTALLED:
#
#     altair:  4.0.1-py_0 conda-forge
#     branca:  0.4.0-py_0 conda-forge
#     folium:  0.5.0-py_0 conda-forge
#     vincent: 0.4.4-py_1 conda-forge
#
#
# Downloading and Extracting Packages
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Libraries imported.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#         Key                        Author  \
# 0  LLVNZ6DK                 Bump, Bethany
# 1  7SR4D9GF                 Bump, Bethany
# 2  UNKZ8FUP  Hughes, Steve; Barnes, Steve
# 3  TLRK9FH4             Williams, Michael
# 4  H9UT659Q                Rulison, Larry
#
#                                                Title Publication Title  \
# 0  Cuomo: Still no cases of coronavirus in NY, bu...       Times Union
# 1  Capital Region hospitals restrict visitors to ...       Times Union
# 2  Albany cancels St. Patrick's Day parade amid c...       Times Union
# 3  Albany's Basketball Fan Fest, TU Center Watch ...       Times Union
# 4  Precautions being taken for cancer patients am...       Times Union
#
#                                                  Url       Date      CiteKey  \
# 0  https://www.timesunion.com/news/article/Cuomo-...  1/30/2020    TU1302020
# 1  https://www.timesunion.com/news/article/Capita...  3/11/2020  TU3112020.1
# 2  https://www.timesunion.com/news/article/Albany...  3/12/2020  TU3122020.1
# 3  https://www.timesunion.com/business/article/Al...  3/12/2020  TU3122020.2
# 4  https://www.timesunion.com/business/article/Pr...  3/12/2020  TU3122020.4
#
#      Location      Lat      Lon Classification
# 0  Albany, NY  42.6526 -73.7562        Medical
# 1  Albany, NY  42.6526 -73.7562        Medical
# 2  Albany, NY  42.6526 -73.7562         Social
# 3  Albany, NY  42.6526 -73.7562         Social
# 4  Albany, NY  42.6526 -73.7562        Medical

# %%
df_cvd19 = df_data_1[['CiteKey','Lat','Lon','Classification']]
df_cvd19.head()
# Out:
#        CiteKey      Lat      Lon Classification
# 0    TU1302020  42.6526 -73.7562        Medical
# 1  TU3112020.1  42.6526 -73.7562        Medical
# 2  TU3122020.1  42.6526 -73.7562         Social
# 3  TU3122020.2  42.6526 -73.7562         Social
# 4  TU3122020.4  42.6526 -73.7562        Medical

# %%
locations = df_cvd19[['Lat', 'Lon']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist
# Out:
# [[42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [40.6687141, -74.11430909999999],
#  [40.6687141, -74.11430909999999],
#  [40.739064, -73.975279],
#  [40.739064, -73.975279],
#  [40.739064, -73.975279],
#  [39.870018, -75.094636],
#  [40.8859326, -74.0434736],
#  [40.8859326, -74.0434736],
#  [40.8859326, -74.0434736],
#  [40.8859326, -74.0434736],
#  [40.6834349, -74.442653],
#  [40.6834349, -74.442653],
#  [40.693538000000004, -73.98778100000001],
#  [40.690811, -73.98804799999999],
#  [40.634681, -74.010802],
#  [41.136390999999996, -73.68892199999999],
#  [39.9487239, -75.1023969],
#  [39.9348351, -75.0307264],
#  [39.9348351, -75.0307264],
#  [39.9348351, -75.0307264],
#  [42.869995, -73.823955],
#  [42.85906, -73.81971300000001],
#  [40.858432799999996, -74.16375529999999],
#  [39.897577000000005, -74.952466],
#  [41.021227, -73.874526],
#  [40.4278841, -74.415984],
#  [42.597262, -73.677223],
#  [40.5187154, -74.4120953],
#  [40.5187154, -74.4120953],
#  [40.8928771, -73.9726381],
#  [40.8928771, -73.9726381],
#  [40.737551, -74.180195],
#  [40.737551, -74.180195],
#  [40.5123258, -74.85933179999999],
#  [40.764353, -73.830244],
#  [40.764353, -73.830244],
#  [40.8509333, -73.9701382],
#  [40.8509333, -73.9701382],
#  [40.8509333, -73.9701382],
#  [40.651769200000004, -74.32292640000001],
#  [39.838169799999996, -74.9648887],
#  [40.618004, -74.313407],
#  [40.618004, -74.313407],
#  [40.230703000000005, -74.723566],
#  [40.4156635, -74.19097690000001],
#  [40.743990600000004, -74.0323626],
#  [40.743990600000004, -74.0323626],
#  [40.743990600000004, -74.0323626],
#  [40.743990600000004, -74.0323626],
#  [40.731868, -74.059075],
#  [40.731868, -74.059075],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [43.425427, -73.712814],
#  [40.8528777, -74.0420848],
#  [40.3367769, -74.0470837],
#  [40.3367769, -74.0470837],
#  [40.798878, -73.13635699999999],
#  [40.798878, -73.13635699999999],
#  [42.704722, -73.754722],
#  [40.291136, -74.340961],
#  [40.757218, -73.971213],
#  [40.758302, -73.985585],
#  [40.758302, -73.985585],
#  [40.716927, -74.007265],
#  [40.494469, -74.446431],
#  [40.494469, -74.446431],
#  [40.260582, -74.274689],
#  [40.260582, -74.274689],
#  [40.7967667, -74.4815438],
#  [40.7967667, -74.4815438],
#  [40.789433, -74.465663],
#  [40.789433, -74.465663],
#  [40.7967667, -74.4815438],
#  [40.7967667, -74.4815438],
#  [40.4862158, -74.4518188],
#  [40.920132, -73.78593599999999],
#  [40.920132, -73.78593599999999],
#  [40.920132, -73.78593599999999],
#  [40.920132, -73.78593599999999],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.712826, -74.00607],
#  [40.689612, -74.174447],
#  [40.735657, -74.1723667],
#  [40.730195, -74.174262],
#  [40.735657, -74.1723667],
#  [40.735657, -74.1723667],
#  [40.8223223, -74.15986629999999],
#  [40.916765399999996, -74.171811],
#  [40.348718100000006, -74.6590472],
#  [40.713716999999995, -73.828168],
#  [40.713716999999995, -73.828168],
#  [40.347054299999996, -74.0643065],
#  [42.729054, -73.685888],
#  [40.214554299999996, -74.61932320000001],
#  [41.147605, -73.991416],
#  [42.761590000000005, -73.930285],
#  [42.999194, -73.850685],
#  [43.083359, -73.784237],
#  [40.471374, -74.350961],
#  [42.810157000000004, -73.939541],
#  [42.820085999999996, -73.916522],
#  [42.815577000000005, -73.930615],
#  [42.812195, -73.94211800000001],
#  [40.8975992, -74.0159727],
#  [40.8975992, -74.0159727],
#  [40.8975992, -74.0159727],
#  [40.8975992, -74.0159727],
#  [40.2170534, -74.7429385],
#  [40.697601899999995, -74.26320240000001],
#  [40.925376299999996, -74.2765368],
#  [40.787878799999994, -74.0143064],
#  [40.787878799999994, -74.0143064],
#  [41.030875, -73.767788],
#  [41.030875, -73.767788],
#  [41.030875, -73.767788],
#  [41.030875, -73.767788],
#  [41.030875, -73.767788],
#  [40.825761, -74.402211],
#  [41.033379, -73.76548000000001]]

# %%
map_nynj = folium.Map(location=[40.764115, -74.011843], zoom_start=10)
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point], popup=df_cvd19['CiteKey'][point]).add_to(map_nynj)
map_nynj
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
body = client_1ee56914d58741c6b2b0e25da68c94e7.get_object(Bucket='courseracapstoneproject-donotdelete-pr-wwgag4s7emu6id',Key='COVID19m_Cites_Dataset.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_2 = pd.read_csv(body)
df_data_2.head()
# Out:
#          Key                Author  \
# 0  S5FARRQFB     Torrejon, Rodrigo
# 1  S5FARRQFA     Torrejon, Rodrigo
# 2  S5FARRQFC     Torrejon, Rodrigo
# 3   BFLTBP4N  Goudsward, Andrew J.
# 4   XHSP5S5P            Walsh, Jim
#
#                                                Title  Publication Title  \
# 0  Bergen County’s 2 new coronavirus cases bring ...  NJ Advanced Media
# 1  Bergen County’s 2 new coronavirus cases bring ...  NJ Advanced Media
# 2  Bergen County’s 2 new coronavirus cases bring ...  NJ Advanced Media
# 3  Coronavirus in NJ: Manalapan man is Monmouth C...  Asbury Park Press
# 4  Coronavirus patient in Cherry Hill is improvin...       Courier-Post
#
#                                                  Url       Date       CiteKey  \
# 0  https://www.nj.com/coronavirus/2020/03/bergen-...  3/13/2020   AJAM3132020
# 1  https://www.nj.com/coronavirus/2020/03/bergen-...  3/13/2020   AJAM3132020
# 2  https://www.nj.com/coronavirus/2020/03/bergen-...  3/13/2020   AJAM3132020
# 3  https://www.app.com/story/news/health/2020/03/...  3/12/2020  APP3122020.2
# 4  https://www.courierpostonline.com/story/news/2...  3/10/2020   CP3102020.1
#
#           Location        Lat        Lon Classification
# 0      Hoboken, NJ  40.743991 -74.032363        Medical
# 1  Jersey City, NJ  40.728158 -74.077642        Medical
# 2   Morristown, NJ  40.796767 -74.481544        Medical
# 3    Manalapan, NJ  40.291136 -74.340961        Medical
# 4  Cherry Hill, NJ  39.934835 -75.030726        Medical

# %%
df_cvd19m = df_data_2[['CiteKey','Lat','Lon','Classification']]
df_cvd19m.head()
# Out:
#         CiteKey        Lat        Lon Classification
# 0   AJAM3132020  40.743991 -74.032363        Medical
# 1   AJAM3132020  40.728158 -74.077642        Medical
# 2   AJAM3132020  40.796767 -74.481544        Medical
# 3  APP3122020.2  40.291136 -74.340961        Medical
# 4   CP3102020.1  39.934835 -75.030726        Medical

# %%
locationsm = df_cvd19m[['Lat', 'Lon']]
locationlist2 = locationsm.values.tolist()
len(locationlist2)
locationlist2
# Out:
# [[40.743990600000004, -74.0323626],
#  [40.7281575, -74.0776417],
#  [40.7967667, -74.4815438],
#  [40.291136, -74.340961],
#  [39.9348351, -75.0307264],
#  [39.9348351, -75.0307264],
#  [39.897577000000005, -74.952466],
#  [40.787878799999994, -74.0143064],
#  [40.7281575, -74.0776417],
#  [40.735657, -74.1723667],
#  [40.743990600000004, -74.0323626],
#  [40.7281575, -74.0776417],
#  [40.743990600000004, -74.0323626],
#  [40.7281575, -74.0776417],
#  [41.033379, -73.76548000000001],
#  [41.021227, -73.874526],
#  [40.4278841, -74.415984],
#  [40.5187154, -74.4120953],
#  [40.7967667, -74.4815438],
#  [40.789433, -74.465663],
#  [40.730195, -74.174262],
#  [40.8859326, -74.0434736],
#  [40.214554299999996, -74.61932320000001],
#  [40.348718100000006, -74.6590472],
#  [40.8859326, -74.0434736],
#  [40.494469, -74.446431],
#  [40.260582, -74.274689],
#  [40.8928771, -73.9726381],
#  [40.8975992, -74.0159727],
#  [40.347054299999996, -74.0643065],
#  [40.7967667, -74.4815438],
#  [40.916765399999996, -74.171811],
#  [40.651769200000004, -74.32292640000001],
#  [40.735657, -74.1723667],
#  [40.8859326, -74.0434736],
#  [40.737551, -74.180195],
#  [40.731868, -74.059075],
#  [40.494469, -74.446431],
#  [40.260582, -74.274689],
#  [40.8975992, -74.0159727],
#  [40.787878799999994, -74.0143064],
#  [40.8509333, -73.9701382],
#  [39.9348351, -75.0307264],
#  [40.8928771, -73.9726381],
#  [40.6834349, -74.442653],
#  [40.858432799999996, -74.16375529999999],
#  [40.4156635, -74.19097690000001],
#  [40.3367769, -74.0470837],
#  [40.8975992, -74.0159727],
#  [40.8509333, -73.9701382],
#  [40.8223223, -74.15986629999999],
#  [40.712826, -74.00607],
#  [40.739064, -73.975279],
#  [41.030875, -73.767788],
#  [40.712826, -74.00607],
#  [40.739064, -73.975279],
#  [40.712826, -74.00607],
#  [40.798878, -73.13635699999999],
#  [40.920132, -73.78593599999999],
#  [40.757218, -73.971213],
#  [40.920132, -73.78593599999999],
#  [40.693538000000004, -73.98778100000001],
#  [40.798878, -73.13635699999999],
#  [40.712826, -74.00607],
#  [41.030875, -73.767788],
#  [40.690811, -73.98804799999999],
#  [40.6687141, -74.11430909999999],
#  [40.8975992, -74.0159727],
#  [40.739064, -73.975279],
#  [41.030875, -73.767788],
#  [40.8859326, -74.0434736],
#  [41.030875, -73.767788],
#  [40.8509333, -73.9701382],
#  [40.697601899999995, -74.26320240000001],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.869995, -73.823955],
#  [40.712826, -74.00607],
#  [42.820085999999996, -73.916522],
#  [42.6526, -73.7562],
#  [42.815577000000005, -73.930615],
#  [42.6526, -73.7562],
#  [42.812195, -73.94211800000001],
#  [40.758302, -73.985585],
#  [42.761590000000005, -73.930285],
#  [42.999194, -73.850685],
#  [40.712826, -74.00607],
#  [40.6687141, -74.11430909999999],
#  [40.758302, -73.985585],
#  [40.920132, -73.78593599999999],
#  [40.712826, -74.00607],
#  [42.6526, -73.7562]]

# %%
map_nynj2 = folium.Map(location=[40.764115, -74.011843], zoom_start=10)
for point in range(0, len(locationlist2)):
    folium.Marker(locationlist2[point], popup=df_cvd19m['CiteKey'][point],icon=folium.Icon(color='red',icon='info-sign')).add_to(map_nynj2)
map_nynj2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
body = client_1ee56914d58741c6b2b0e25da68c94e7.get_object(Bucket='courseracapstoneproject-donotdelete-pr-wwgag4s7emu6id',Key='COVID19s_Cites_Dataset.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_3 = pd.read_csv(body)
df_data_3.head()
# Out:
#         Key      Author                                              Title  \
# 0  3B978YF6  Radel, Dan  Saltwater Fishing Expo canceled due to coronav...
# 1  BN6KJA5N  Makin, Bob         Coronavirus cancels Rutgers Dance Marathon
# 2  9ZV94PYA  Walsh, Jim  Rutgers, Stockton will extend breaks, teach on...
# 3  4WQPD7N2  Walsh, Jim  Trenton diocese mandates precautions against c...
# 4  2RZP224Y  Walsh, Jim  Camden County cancels events for seniors due t...
#
#           Publication Title  \
# 0         Asbury Park Press
# 1  Bridgewater Courier News
# 2              Courier-Post
# 3              Courier-Post
# 4              Courier-Post
#
#                                                  Url       Date       CiteKey  \
# 0  https://www.app.com/story/sports/outdoors/fish...  3/12/2020  APP3122020.1
# 1  https://www.mycentraljersey.com/story/news/edu...   3/9/2020     BCN392020
# 2  https://www.courierpostonline.com/story/news/2...  3/10/2020   CP3102020.2
# 3  https://www.courierpostonline.com/story/news/2...   3/4/2020      CP342020
# 4  https://www.courierpostonline.com/story/news/2...   3/9/2020    CP392020.1
#
#                           Location        Lat        Lon Classification
# 0                       Edison, NJ  40.518715 -74.412095         Social
# 1                New Brunswick, NJ  40.486216 -74.451819         Social
# 2                       Camden, NJ  39.948724 -75.102397         Social
# 3                      Trenton, NJ  40.217053 -74.742938         Social
# 4  Bellmawr Ballroom, Bellmawr, NJ  39.870018 -75.094636         Social

# %%
df_cvd19s = df_data_3[['CiteKey','Lat','Lon','Classification']]
df_cvd19s.head()
# Out:
#         CiteKey        Lat        Lon Classification
# 0  APP3122020.1  40.518715 -74.412095         Social
# 1     BCN392020  40.486216 -74.451819         Social
# 2   CP3102020.2  39.948724 -75.102397         Social
# 3      CP342020  40.217053 -74.742938         Social
# 4    CP392020.1  39.870018 -75.094636         Social

# %%
locationss = df_cvd19s[['Lat', 'Lon']]
locationlist3 = locationss.values.tolist()
len(locationlist3)
locationlist3
# Out:
# [[40.5187154, -74.4120953],
#  [40.4862158, -74.4518188],
#  [39.9487239, -75.1023969],
#  [40.2170534, -74.7429385],
#  [39.870018, -75.094636],
#  [39.838169799999996, -74.9648887],
#  [40.731868, -74.059075],
#  [40.7281575, -74.0776417],
#  [40.7281575, -74.0776417],
#  [41.147605, -73.991416],
#  [41.030875, -73.767788],
#  [41.136390999999996, -73.68892199999999],
#  [40.471374, -74.350961],
#  [40.618004, -74.313407],
#  [40.618004, -74.313407],
#  [40.5123258, -74.85933179999999],
#  [40.789433, -74.465663],
#  [40.8528777, -74.0420848],
#  [40.735657, -74.1723667],
#  [40.230703000000005, -74.723566],
#  [40.925376299999996, -74.2765368],
#  [40.737551, -74.180195],
#  [40.7281575, -74.0776417],
#  [40.6834349, -74.442653],
#  [40.3367769, -74.0470837],
#  [40.7967667, -74.4815438],
#  [40.825761, -74.402211],
#  [40.743990600000004, -74.0323626],
#  [40.634681, -74.010802],
#  [40.716927, -74.007265],
#  [40.713716999999995, -73.828168],
#  [40.713716999999995, -73.828168],
#  [40.764353, -73.830244],
#  [40.920132, -73.78593599999999],
#  [42.597262, -73.677223],
#  [42.704722, -73.754722],
#  [42.6526, -73.7562],
#  [42.6526, -73.7562],
#  [42.729054, -73.685888],
#  [42.810157000000004, -73.939541],
#  [42.85906, -73.81971300000001],
#  [43.425427, -73.712814],
#  [43.083359, -73.784237],
#  [40.764353, -73.830244],
#  [40.689612, -74.174447],
#  [40.712826, -74.00607],
#  [42.6526, -73.7562]]

# %%
map_nynj3 = folium.Map(location=[40.764115, -74.011843], zoom_start=10)
for point in range(0, len(locationlist3)):
    folium.Marker(locationlist3[point], popup=df_cvd19s['CiteKey'][point],icon=folium.Icon(color='green',icon='info-sign')).add_to(map_nynj3)
map_nynj3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_nynj4 = folium.Map(location=[40.764115, -74.011843], zoom_start=10)
for point in range(0, len(locationlist3)):
    folium.Marker(locationlist3[point], popup=df_cvd19s['CiteKey'][point],icon=folium.Icon(color='green',icon='info-sign')).add_to(map_nynj4)
for point in range(0, len(locationlist2)):
    folium.Marker(locationlist2[point], popup=df_cvd19m['CiteKey'][point],icon=folium.Icon(color='red',icon='info-sign')).add_to(map_nynj4)
map_nynj4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_nynj4.save(outfile='map_nynj4.html')
